# %%
import pandas as pp
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

data=pp.read_csv("study.csv")
data
# Out:
#     study_hours  sleep_hours  practice_hours  exam_score
# 0             9            4              11          90
# 1             6           11               7          78
# 2             8            9               7          90
# 3             7           10               7          82
# 4             6            7              11          80
# 5            10            7               7          88
# 6             7            9               8          86
# 7             8            7               9          91
# 8             7            7              10          87
# 9             2           16               6          66
# 10            7            5              12          84
# 11            8            8               8          83
# 12            6           13               5          60
# 13            8            4              12          96
# 14            7            9               8          88
# 15           11            6               7          93
# 16           10            6               8          89
# 17            9            7               8          85
# 18            7           10               7          84
# 19            6           10               8          81
# 20            9            5              10          98
# 21            5           15               4          45
# 22            6           10               8          83
# 23            9            7               8          86
# 24            7           11               6          77
# 25            2           15               7          82
# 26            8            9               7          95
# 27            4           16               4          54
# 28            4           10              10          84

# %%
X= data.drop(columns=['exam_score'])
y=data['exam_score']

model=DecisionTreeClassifier()
model.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
tree.export_graphviz(model,out_file='exam.dot',feature_names=['study_hours','sleep_hours','practice_hours'],
                     label='all',
                     rounded=True,
                     filled=True)
